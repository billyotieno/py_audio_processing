# %%
# Import core packages and modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# File reading modules
from glob import glob

# Audio Processing Libraries
import librosa as lr

# %%
# Set directory for source files
data_dir = './set_a'
audio_files = glob(data_dir + '/*.wav')

# %%
# Check the length of the Audio Files
len(audio_files)
# Out:
# 176

# %%
# Read in first audio file, create the time array (timeline)
audio, sfreq = lr.load(audio_files[10])
time = np.arange(0, len(audio)) / sfreq

print(time)
# Out:
# [0.00000000e+00 4.53514739e-05 9.07029478e-05 ... 8.99986395e+00
#  8.99990930e+00 8.99995465e+00]

# %%
# Plot the audio overtime
fig, ax = plt.subplots()
ax.plot(time, audio)
ax.set(xlabel="Time (s)", ylabel="Sound Amplitude")
plt.show()

# %%
# Function to Run Through all Audio Files
def get_audio_time(audio_file):
    """ Function extracts the audio and frequency
        from audio file and returns the audio & time
    """
    audio, sfreq = lr.load(audio_file)
    time = np.arange(0, len(audio)) / sfreq
    return audio, time

def plot_audio_amplitude(audio, time):
    """
    :param audio: audio file
    :param time:  time frequency for the audio
    :return: None
    """
    fig, ax = plt.subplots()
    ax.plot(time, audio)
    ax.set(xlabel="Time (s)", ylabel="Sound Amplitude")
    plt.show()

for audio_file in audio_files:
    plot_audio_amplitude(*get_audio_time(audio_file))
